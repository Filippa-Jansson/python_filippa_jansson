# %% [markdown]
# ### All my imports

# %%
import os
from circle import Circle
from rectangle import Rectangle
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, Rectangle

# %% [markdown]
# ### Testing the shapes

# %%
circle1 = Circle(x=1, y=1, radius=1)
circle2 = Circle(x=1, y=1, radius=1)
rectangle1 = Rectangle(x=0, y=0, width=1, height=1)
rectangle2 = Rectangle(x=0, y=0, width=3, height=5)

print(circle1)
print(circle2)
print(rectangle1)
print(rectangle2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 circle1 = Circle(x=1, y=1, radius=1)
#       2 circle2 = Circle(x=1, y=1, radius=1)
#       3 rectangle1 = Rectangle(x=0, y=0, width=1, height=1)
#
# TypeError: Circle.__init__() missing 1 required positional argument: 'xy'

# %%
print("circle1 == circle2:", circle1 == circle2)
print("circle1 >= Circle(radius=0.5):", circle1 >= circle3)
# Out:
# circle1 == circle2: True
# circle1 >= Circle(radius=0.5): False

# %%
print("Before move:", circle1)
circle1.translate(5, 3)
print("After move:", circle1)

try:
    circle1.translate("THREE", 5)
except TypeError as e:
    print("Caught error:", e)
# Out:
# Before move: Circle with center (1, 1) and radius 1
# After move: Circle with center (6, 4) and radius 1
# Caught error: dx and dy must be numeric values (int or float).

# %%
print("circle1 area:", circle1.area)
print("circle1 perimeter:", circle1.perimeter)

print("rectangle1 area:", rectangle1.area)
print("rectangle1 perimeter:", rectangle1.perimeter)
# Out:
# circle1 area: 3.141592653589793
# circle1 perimeter: 6.283185307179586
# rectangle1 area: 1
# rectangle1 perimeter: 4

# %%
for shape in [rectangle1, rectangle2, circle1, circle2]:
    shape.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 for shape in [rectangle1, rectangle2, circle1, circle2]:
# ----> 2     shape.plot()
#
# AttributeError: 'Rectangle' object has no attribute 'plot'
